# %%
import os

print(os.listdir("../audio"))
# Out:
# ['calls_audio', 'call_transcripts.csv', 'data_description.csv', 'final_transcripts_enriched.csv', 'final_transcripts_enriched_v2.csv']

# %%
print(os.listdir("../audio/calls_audio")[:5])
# Out:
# ['call_recording_01.wav', 'call_recording_02.wav', 'call_recording_03.wav', 'call_recording_04.wav', 'call_recording_05.wav']

# %%
import shutil

print(shutil.which("ffmpeg"))
# Out:
# C:\Users\Samjhana Yadav\AppData\Local\Microsoft\WinGet\Packages\Gyan.FFmpeg.Essentials_Microsoft.Winget.Source_8wekyb3d8bbwe\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.EXE

# %%
import whisper
import os

# Load Whisper model
model = whisper.load_model("base")

# Folder paths
audio_folder = "../audio/calls_audio"
output_folder = "../transcripts"

# Create transcripts folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process all audio files
for file in os.listdir(audio_folder):
    if file.endswith(".wav") or file.endswith(".mp3"):

        print(f"Processing: {file}")

        audio_path = os.path.join(audio_folder, file)

        result = model.transcribe(audio_path)

        output_file = os.path.join(
            output_folder,
            file.replace(".wav", ".txt").replace(".mp3", ".txt")
        )

        with open(output_file, "w", encoding="utf-8") as f:
            f.write(result["text"])

print("✅ All transcripts generated successfully!")
# Out:
# Processing: call_recording_01.wav
# c:\Users\Samjhana Yadav\anaconda3\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Processing: call_recording_02.wav
# Processing: call_recording_03.wav
# Processing: call_recording_04.wav
# Processing: call_recording_05.wav
# Processing: call_recording_06.wav
# Processing: call_recording_07.wav
# Processing: call_recording_08.wav
# Processing: call_recording_09.wav
# Processing: call_recording_10.wav
# Processing: call_recording_11.wav
# Processing: call_recording_12.wav
# Processing: call_recording_13.wav
# Processing: call_recording_14.wav
# Processing: call_recording_15.wav
# Processing: call_recording_16.wav
# Processing: call_recording_17.wav
# Processing: call_recording_18.wav
# Processing: call_recording_19.wav
# Processing: call_recording_20.wav
# ✅ All transcripts generated successfully!
